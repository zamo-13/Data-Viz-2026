# %% [markdown]
# # Data Vis: Visualizing Numerical and Categorical Data
# * Notebook 1: Data Preparation

# %% [markdown]
# ## Setup

# %%
# %pip install missingno
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting missingno
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\moza\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from missingno) (2.1.3)
# Collecting matplotlib (from missingno)
#   Using cached matplotlib-3.10.9-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting scipy (from missingno)
#   Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting seaborn (from missingno)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->missingno)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->missingno)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->missingno)
#   Using cached fonttools-4.62.1-cp312-cp312-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->missingno)
#   Using cached kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\moza\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->missingno) (25.0)
# Collecting pillow>=8 (from matplotlib->missingno)
#   Using cached pillow-12.2.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib->missingno)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\moza\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\moza\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn->missingno) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\moza\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\moza\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\moza\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Using cached matplotlib-3.10.9-cp312-cp312-win_amd64.whl (8.2 MB)
# Using cached scipy-1.17.1-cp312-cp312-win_amd64.whl (36.5 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.62.1-cp312-cp312-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.5.0-cp312-cp312-win_amd64.whl (73 kB)
# Using cached pillow-12.2.0-cp312-cp312-win_amd64.whl (7.1 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: scipy, pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn, missingno
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 missingno-0.5.2 pillow-12.2.0 pyparsing-3.3.2 scipy-1.17.1 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1
# [notice] To update, run: C:\Users\MoZa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import missingno as msno

# %% [markdown]
# # Data

# %% [markdown]
# In this notebook, we will use the NYC Flights 2013 dataset, which contains information about all domestic flights that departed from NYC in 2013. The dataset includes the following tables:
# - `flights`: Contains information about each flight, including the origin and destination airports, departure and arrival times, and delays.
# - `planes`: Contains information about the planes, including their tail numbers and model years.
# - `airports`: Contains information about the airports, including their names and locations.
# - `airlines`: Contains information about the airlines, including their names and IATA codes.
# - `weather`: Contains information about the weather at the origin airports, including temperature, wind speed, and precipitation.

# %% [markdown]
# The dataset is available in the `nycflights13` package.

# %%
from nycflights13 import flights
from nycflights13 import planes
from nycflights13 import airports
from nycflights13 import airlines
from nycflights13 import weather
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from nycflights13 import flights
#       2 from nycflights13 import planes
#       3 from nycflights13 import airports
#
# ModuleNotFoundError: No module named 'nycflights13'

# %% [markdown]
# Let's first look at the main table, that is, `flights`.

# %%
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# 0      1400     5      15  2013-01-01T10:00:00Z
# 1      1416     5      29  2013-01-01T10:00:00Z
# 2      1089     5      40  2013-01-01T10:00:00Z
# 3      1576     5      45  2013-01-01T10:00:00Z
# 4       762     6       0  2013-01-01T11:00:00Z

# %% [markdown]
# Next, we will explore the `planes` table. We rename the `year` column to avoid naming conflicts when joining the tables with others.

# %%
planes.rename(columns={'year': 'year_built'}, inplace=True)
planes
# Out:
#      tailnum  year_built                     type  \
# 0     N10156      2004.0  Fixed wing multi engine
# 1     N102UW      1998.0  Fixed wing multi engine
# 2     N103US      1999.0  Fixed wing multi engine
# 3     N104UW      1999.0  Fixed wing multi engine
# 4     N10575      2002.0  Fixed wing multi engine
# ...      ...         ...                      ...
# 3317  N997AT      2002.0  Fixed wing multi engine
# 3318  N997DL      1992.0  Fixed wing multi engine
# 3319  N998AT      2002.0  Fixed wing multi engine
# 3320  N998DL      1992.0  Fixed wing multi engine
# 3321  N999DN      1992.0  Fixed wing multi engine
#
#                        manufacturer      model  engines  seats  speed  \
# 0                           EMBRAER  EMB-145XR        2     55    NaN
# 1                  AIRBUS INDUSTRIE   A320-214        2    182    NaN
# 2                  AIRBUS INDUSTRIE   A320-214        2    182    NaN
# 3                  AIRBUS INDUSTRIE   A320-214        2    182    NaN
# 4                           EMBRAER  EMB-145LR        2     55    NaN
# ...                             ...        ...      ...    ...    ...
# 3317                         BOEING    717-200        2    100    NaN
# 3318  MCDONNELL DOUGLAS AIRCRAFT CO      MD-88        2    142    NaN
# 3319                         BOEING    717-200        2    100    NaN
# 3320  MCDONNELL DOUGLAS CORPORATION      MD-88        2    142    NaN
# 3321  MCDONNELL DOUGLAS CORPORATION      MD-88        2    142    NaN
#
#          engine
# 0     Turbo-fan
# 1     Turbo-fan
# 2     Turbo-fan
# 3     Turbo-fan
# 4     Turbo-fan
# ...         ...
# 3317  Turbo-fan
# 3318  Turbo-fan
# 3319  Turbo-fan
# 3320  Turbo-jet
# 3321  Turbo-jet
#
# [3322 rows x 9 columns]

# %% [markdown]
# We do the same for the `airports`, `airlines`, and `weather` tables.

# %%
airports.rename(columns={'name': 'airport_name'}, inplace=True)
airports.head()
# Out:
#    faa                   airport_name        lat        lon   alt  tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -6   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -5   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %%
airlines.rename(columns={'name': 'airline_name'}, inplace=True)
airlines.head()
# Out:
#   carrier            airline_name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %%
weather.drop(columns=['time_hour'], inplace=True)
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     1  39.02  26.06  59.37     270.0    10.35702
# 1    EWR  2013      1    1     2  39.02  26.96  61.63     250.0     8.05546
# 2    EWR  2013      1    1     3  39.02  28.04  64.43     240.0    11.50780
# 3    EWR  2013      1    1     4  39.92  28.04  62.21     250.0    12.65858
# 4    EWR  2013      1    1     5  39.02  28.04  64.43     260.0    12.65858
#
#    wind_gust  precip  pressure  visib
# 0        NaN     0.0    1012.0   10.0
# 1        NaN     0.0    1012.3   10.0
# 2        NaN     0.0    1012.5   10.0
# 3        NaN     0.0    1012.2   10.0
# 4        NaN     0.0    1011.9   10.0

# %% [markdown]
# Let's now join the tables together. We use `left joins`, indicate the columns to join on (both in the left and right tables), and specify the suffixes for the columns with naming conflicts.

# %%
flights_joined = flights.merge(airlines, how='left', on='carrier')
flights_joined = flights_joined.merge(planes, how='left', on='tailnum', suffixes=('', '_plane'))
flights_joined = flights_joined.merge(airports, how='left', left_on='origin', right_on='faa', suffixes=('_dest', '_origin'))
flights_joined = flights_joined.merge(airports, how='left', left_on='dest', right_on='faa', suffixes=('_origin', '_dest'))
flights_joined = flights_joined.merge(weather, how='left', left_on=['origin', 'year', 'month', 'day', 'hour'], right_on=['origin', 'year', 'month', 'day', 'hour'], suffixes=('', '_weather'))

# %% [markdown]
# Check the shape of the original `flights` table and the joined table. The joined table should have more columns than the original `flights` table, but the same number of rows.

# %%
flights.shape
# Out:
# (336776, 19)

# %%
flights_joined.shape
# Out:
# (336776, 53)

# %%
flights_joined.head(20)
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   2013      1    1     517.0             515        2.0     830.0
# 1   2013      1    1     533.0             529        4.0     850.0
# 2   2013      1    1     542.0             540        2.0     923.0
# 3   2013      1    1     544.0             545       -1.0    1004.0
# 4   2013      1    1     554.0             600       -6.0     812.0
# 5   2013      1    1     554.0             558       -4.0     740.0
# 6   2013      1    1     555.0             600       -5.0     913.0
# 7   2013      1    1     557.0             600       -3.0     709.0
# 8   2013      1    1     557.0             600       -3.0     838.0
# 9   2013      1    1     558.0             600       -2.0     753.0
# 10  2013      1    1     558.0             600       -2.0     849.0
# 11  2013      1    1     558.0             600       -2.0     853.0
# 12  2013      1    1     558.0             600       -2.0     924.0
# 13  2013      1    1     558.0             600       -2.0     923.0
# 14  2013      1    1     559.0             600       -1.0     941.0
# 15  2013      1    1     559.0             559        0.0     702.0
# 16  2013      1    1     559.0             600       -1.0     854.0
# 17  2013      1    1     600.0             600        0.0     851.0
# 18  2013      1    1     600.0             600        0.0     837.0
# 19  2013      1    1     601.0             600        1.0     844.0
#
#     sched_arr_time  arr_delay carrier  ...           tzone_dest   temp   dewp  \
# 0              819       11.0      UA  ...      America/Chicago  39.02  28.04
# 1              830       20.0      UA  ...      America/Chicago  39.92  24.98
# 2              850       33.0      AA  ...     America/New_York  39.02  26.96
# 3             1022      -18.0      B6  ...                  NaN  39.02  26.96
# 4              837      -25.0      DL  ...     America/New_York  39.92  24.98
# 5              728       12.0      UA  ...      America/Chicago  39.02  28.04
# 6              854       19.0      B6  ...     America/New_York  37.94  28.04
# 7              723      -14.0      EV  ...     America/New_York  39.92  24.98
# 8              846       -8.0      B6  ...     America/New_York  37.94  26.96
# 9              745        8.0      AA  ...      America/Chicago  39.92  24.98
# 10             851       -2.0      B6  ...     America/New_York  37.94  26.96
# 11             856       -3.0      B6  ...     America/New_York  37.94  26.96
# 12             917        7.0      UA  ...  America/Los_Angeles  37.94  26.96
# 13             937      -14.0      UA  ...  America/Los_Angeles  37.94  28.04
# 14             910       31.0      AA  ...      America/Chicago  39.92  24.98
# 15             706       -4.0      B6  ...     America/New_York  39.02  26.96
# 16             902       -8.0      UA  ...  America/Los_Angeles  37.94  28.04
# 17             858       -7.0      B6  ...     America/New_York  39.92  24.98
# 18             825       12.0      MQ  ...     America/New_York  39.92  24.98
# 19             850       -6.0      B6  ...     America/New_York  37.94  28.04
#
#     humid  wind_dir  wind_speed  wind_gust  precip pressure visib
# 0   64.43     260.0    12.65858        NaN     0.0   1011.9  10.0
# 1   54.81     250.0    14.96014   21.86482     0.0   1011.4  10.0
# 2   61.63     260.0    14.96014        NaN     0.0   1012.1  10.0
# 3   61.63     260.0    14.96014        NaN     0.0   1012.1  10.0
# 4   54.81     260.0    16.11092   23.01560     0.0   1011.7  10.0
# 5   64.43     260.0    12.65858        NaN     0.0   1011.9  10.0
# 6   67.21     240.0    11.50780        NaN     0.0   1012.4  10.0
# 7   54.81     260.0    16.11092   23.01560     0.0   1011.7  10.0
# 8   64.29     260.0    13.80936        NaN     0.0   1012.6  10.0
# 9   54.81     260.0    16.11092   23.01560     0.0   1011.7  10.0
# 10  64.29     260.0    13.80936        NaN     0.0   1012.6  10.0
# 11  64.29     260.0    13.80936        NaN     0.0   1012.6  10.0
# 12  64.29     260.0    13.80936        NaN     0.0   1012.6  10.0
# 13  67.21     240.0    11.50780        NaN     0.0   1012.4  10.0
# 14  54.81     260.0    16.11092   23.01560     0.0   1011.7  10.0
# 15  61.63     260.0    14.96014        NaN     0.0   1012.1  10.0
# 16  67.21     240.0    11.50780        NaN     0.0   1012.4  10.0
# 17  54.81     260.0    16.11092   23.01560     0.0   1011.7  10.0
# 18  54.81     260.0    16.11092   23.01560     0.0   1011.7  10.0
# 19  67.21     240.0    11.50780        NaN     0.0   1012.4  10.0
#
# [20 rows x 53 columns]

# %%
flights_joined.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'airline_name', 'year_built', 'type', 'manufacturer',
#        'model', 'engines', 'seats', 'speed', 'engine', 'faa_origin',
#        'airport_name_origin', 'lat_origin', 'lon_origin', 'alt_origin',
#        'tz_origin', 'dst_origin', 'tzone_origin', 'faa_dest',
#        'airport_name_dest', 'lat_dest', 'lon_dest', 'alt_dest', 'tz_dest',
#        'dst_dest', 'tzone_dest', 'temp', 'dewp', 'humid', 'wind_dir',
#        'wind_speed', 'wind_gust', 'precip', 'pressure', 'visib'],
#       dtype='object')

# %% [markdown]
# Use thew `missingno` package to visualize the missing values in the joined table.

# %%
msno.bar(flights_joined.sample(100))
# Out:
# <Axes: >

# %% [markdown]
# Export joined data to a CSV file for later use.

# %%
flights_joined.to_csv('flights_joined.csv', index=False)
